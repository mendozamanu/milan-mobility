# %%
import pandas as pd
import numpy as np
import csv

# %%
with open('./classif20x20week_callout/csv/classif20x20week_callout_filtered.csv', newline='\n') as csvfile:
    clas = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in clas:
        print(row)
# Out:
# 0.004171170375202154
# 0.0020196448327967206
# 0.017197030510360502
# 0.0671175421906477
# 0.03039526740848402
# 0.09446447050410403
# 0.017531070830308595
# 0.0359676126631346
# 0.011573090787288392
# 0.017073587433043068
# 0.005615473906756023
# 0.006905512295785363
# 0.003499291236375038
# 0.004236018486850858
# 0.003424239373005581
# 0.0012858338083317482
# 0.0030390675654132218
# 0.000840784211017388
# 0.002999942300606955
# 0.0010275819951147142
# 0.002415726783756647
# 0.0008862143925233733
# 0.001223958188551523
# 0.00039890360769447106
# 0.0018373007562708982
# 0.0003190373651171592
# 0.0021693654944388826
# 7.730494336797498e-05
# 0.0020885964842408357
# 0.0
# 0.002035179816813847
# 6.836323520440204e-06
# 0.0033261246982580948
# 0.0009059664257216061
# 0.006154146053735108
# 0.0022084853204027534
# 0.005010600924843544
# 0.0017570428189008888
# 0.0019654931593545695
# 0.0005503510790437209
# 0.0072487984792941286
# 0.0016779274210079486
# 0.01653772845845421
# ...

# %%
with open('./classif20x20week_callout/classif20x20week_callout10_iterative/classif20x20week_callout0.test', newline='\n') as csvfile:
    clas2 = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in clas2:
        print(row)
# Out:
# ['[MULTILABEL,', 'DENSE]']
# ['$', '39']
# ['$', '168']
# ['$', '6']
# ...

# %%
#clas y clas2
for row in clas2:
    for rowi in clas:
