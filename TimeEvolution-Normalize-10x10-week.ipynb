# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
dfs = pd.DataFrame({})

for i in range(4,10):
    df = pd.read_csv('./csv/sms-call-internet-mi-2013-11-0{}.csv'.format(i), parse_dates=['time'])
    dfs = dfs.append(df)
df = pd.read_csv('./csv/sms-call-internet-mi-2013-11-10.csv', parse_dates=['time'])
dfs = dfs.append(df)
dfs = dfs.fillna(0)

# %%
#Group by hours and aggregate values according to each cell/hour
dfgr = dfs[['cellid', 'time', 'smsin','smsout', 'callin','callout', 'internet']].groupby(['time', 'cellid'], as_index=False).sum()
dfgr['hour'] = dfgr.time.dt.hour+24*(dfgr.time.dt.day-4)
dfgg = dfgr[['hour', 'cellid', 'time', 'smsin','smsout', 'callin','callout', 'internet']].groupby(['hour', 'cellid'], as_index=False).sum()
#dfgg = dfgg.set_index(['hour']).sort_index()
print(dfgg)

#Group by hours and aggregate values according to the hour
#dfgr = dfs[['cellid', 'time', 'smsin','smsout', 'callin','callout', 'internet']].groupby(['time', 'cellid'], as_index=False).sum()
#dfgr['hour'] = dfgr.time.dt.hour+24*(dfgr.time.dt.day-1)
#dfgg = dfgr[['hour', 'time', 'smsin','smsout', 'callin','callout', 'internet']].groupby(['hour'], as_index=False).sum()
#dfgg = dfgg.set_index(['hour']).sort_index()
#print(dfgg)
# Out:
#          hour  cellid     smsin    smsout    callin   callout    internet
# 0           0       1  1.134621  0.806930  0.055225  0.215539   50.341965
# 1           0       2  1.152227  0.822611  0.055578  0.219547   50.432001
# 2           0       3  1.170967  0.839303  0.055954  0.223814   50.527840
# 3           0       4  1.083627  0.761510  0.054203  0.203928   50.081175
# 4           0       5  0.995433  0.707518  0.053310  0.186448   45.571568
# ...       ...     ...       ...       ...       ...       ...         ...
# 1679990   167    9996  6.054090  6.946597  1.640647  4.461988  277.006021
# 1679991   167    9997  7.169133  6.872796  1.482668  5.482080  280.252966
# 1679992   167    9998  6.950347  6.901188  1.509687  5.291210  280.206203
# 1679993   167    9999  4.068024  4.816966  1.490447  2.965692  214.932905
# 1679994   167   10000  3.580726  2.847060  1.250935  2.658222  181.829832
#
# [1679995 rows x 7 columns]

# %%
l=[] #choosen cells on 10x10 grid
for i in range(4273,5273,100):
    for j in range(i,i+10):
        l.append(j)

# %%
df10 = pd.DataFrame({})
for el in dfgg.iterrows():
    if(l.count(int(el[1].cellid))==1):
        tmp = pd.DataFrame([[int(el[1].hour), int(el[1].cellid), el[1].smsin, el[1].smsout, el[1].callin, el[1].callout, el[1].internet]], columns=['hour', 'cellid', 'smsin','smsout', 'callin','callout', 'internet'])
        df10=df10.append(tmp)

# %%
df10 = df10.set_index(['hour']).sort_index()
print(df10)
# Out:
#       cellid     smsin    smsout    callin   callout    internet
# hour
# 0       4273  8.210250  1.387363  0.376396  3.394311  649.389502
# 0       4274  3.871296  1.188116  1.414780  1.719770  199.237781
# 0       4275  6.017584  3.723436  2.091439  2.581571  220.399774
# 0       4276  9.368356  6.660107  3.593219  3.048151  379.562450
# 0       4277  9.928277  6.678112  4.086494  2.934664  411.105798
# ...      ...       ...       ...       ...       ...         ...
# 167     5178  7.079475  5.160725  4.407656  1.727244  335.069609
# 167     5179  8.316477  5.048183  4.181287  2.045839  350.433594
# 167     5180  9.565491  6.083170  3.077989  3.371633  359.659132
# 167     5181  8.292050  4.566094  2.691010  2.742752  321.769054
# 167     5182  3.034287  1.182458  1.139238  0.945481  115.215237
#
# [16800 rows x 6 columns]

# %%
cells = df10.cellid
scaler=MinMaxScaler()
scaled = pd.DataFrame(scaler.fit_transform(df10), columns=df10.columns, index=df10.index)

# %%
dfgg=scaled
dfgg['cellid']=cells
print(dfgg)
# Out:
#       cellid     smsin    smsout    callin   callout  internet
# hour
# 0       4273  0.003091  0.000607  0.000339  0.002678  0.055906
# 0       4274  0.001457  0.000520  0.001274  0.001357  0.016595
# 0       4275  0.002265  0.001629  0.001883  0.002037  0.018443
# 0       4276  0.003527  0.002914  0.003235  0.002405  0.032342
# 0       4277  0.003737  0.002922  0.003679  0.002315  0.035097
# ...      ...       ...       ...       ...       ...       ...
# 167     5178  0.002665  0.002258  0.003968  0.001363  0.028457
# 167     5179  0.003131  0.002209  0.003764  0.001614  0.029799
# 167     5180  0.003601  0.002662  0.002771  0.002660  0.030604
# 167     5181  0.003121  0.001998  0.002423  0.002164  0.027295
# 167     5182  0.001142  0.000517  0.001026  0.000746  0.009257
#
# [16800 rows x 6 columns]

# %%
dfsi = [] #data from df without indexing
dfsi2 = pd.DataFrame({}) #new df to save
dfso = []
dfso2 = pd.DataFrame({})
dfci = []
dfci2 = pd.DataFrame({})
dfco = []
dfco2 = pd.DataFrame({})
dfin = []
dfin2 = pd.DataFrame({})

dfsi.append(dfgg.loc[0].cellid)
dfso.append(dfgg.loc[0].cellid)
dfci.append(dfgg.loc[0].cellid)
dfco.append(dfgg.loc[0].cellid)
dfin.append(dfgg.loc[0].cellid)

dfsi2["cellid"]=dfsi[0].values
dfso2["cellid"]=dfsi[0].values
dfci2["cellid"]=dfsi[0].values
dfco2["cellid"]=dfsi[0].values
dfin2["cellid"]=dfsi[0].values
for i in range(0, dfgr.hour.max()+1): #dfgr.hour.max()+1
    #row[0] - hour, row[1]: df cols
    dfsi.append(dfgg.loc[i].smsin)
    dfsi2["smsin"+str(i)]=dfsi[i+1].values
    
    dfso.append(dfgg.loc[i].smsout)
    dfso2["smsout"+str(i)]=dfso[i+1].values
    
    dfci.append(dfgg.loc[i].callin)
    dfci2["callin"+str(i)]=dfci[i+1].values
    
    dfco.append(dfgg.loc[i].callout)
    dfco2["callout"+str(i)]=dfco[i+1].values
    
    dfin.append(dfgg.loc[i].internet)
    dfin2["internet"+str(i)]=dfin[i+1].values

# %%
dfsi2.to_csv("./classif/weekly10x10/classif10x10week_smsin.csv")
dfsi2.head()
# Out:
#    cellid    smsin0    smsin1    smsin2    smsin3    smsin4    smsin5  \
# 0    4273  0.003091  0.000865  0.000291  0.000535  0.003332  0.006599
# 1    4274  0.001457  0.001226  0.000657  0.001418  0.006654  0.015169
# 2    4275  0.002265  0.001381  0.000734  0.001195  0.003776  0.008815
# 3    4276  0.003527  0.002668  0.001322  0.000794  0.001982  0.001206
# 4    4277  0.003737  0.003293  0.001626  0.000878  0.002634  0.001323
#
#      smsin6    smsin7    smsin8  ...  smsin158  smsin159  smsin160  smsin161  \
# 0  0.007458  0.010923  0.017015  ...  0.006135  0.005582  0.004282  0.004947
# 1  0.016008  0.020835  0.029589  ...  0.000747  0.000871  0.001017  0.001047
# 2  0.010730  0.018023  0.030304  ...  0.002781  0.003779  0.003715  0.004070
# 3  0.002872  0.008090  0.022986  ...  0.011149  0.011733  0.011447  0.013233
# 3   0.019030   0.026159   0.026465   0.019850   0.015109   0.008368   0.004290
# 4   0.021331   0.031754   0.029670   0.021214   0.017510   0.009460   0.004741
#
# [5 rows x 169 columns]

# %%
dfco2.to_csv("./classif/weekly10x10/classif10x10week_callout.csv")
dfco2.head()
# Out:
#    cellid  callout0  callout1  callout2  callout3  callout4  callout5  \
# 0    4273  0.002678  0.000982  0.000807  0.002401  0.015560  0.023927
# 1    4274  0.001357  0.000442  0.002491  0.005958  0.030701  0.046050
# 2    4275  0.002037  0.000354  0.002689  0.005001  0.021613  0.031095
# 3    4276  0.002405  0.000086  0.001160  0.001373  0.004950  0.008469
# 4    4277  0.002315  0.000000  0.001136  0.001590  0.005907  0.010472
#
#    callout6  callout7  callout8  ...  callout158  callout159  callout160  \
# 0  0.028174  0.032004  0.035301  ...    0.027791    0.016893    0.016193
# 1  0.053380  0.061968  0.056420  ...    0.008211    0.005912    0.004951
# 2  0.039257  0.050777  0.052425  ...    0.010491    0.009638    0.008881
# 3  0.011876  0.018605  0.031989  ...    0.014454    0.013211    0.016281
# 4  0.013014  0.019988  0.033154  ...    0.016247    0.013515    0.019233
#
#    callout161  callout162  callout163  callout164  callout165  callout166  \
# 0    0.028197    0.032102    0.017428    0.018802    0.014958    0.008589
# 1    0.009712    0.008425    0.008958    0.006629    0.003691    0.003922
# 2    0.014033    0.012561    0.011985    0.011078    0.005956    0.005753
# 3    0.022223    0.026027    0.022993    0.026454    0.015195    0.008833
# 4    0.025197    0.029923    0.028267    0.030269    0.019118    0.010592
#
#    callout167
# 0    0.001224
# 1    0.000899
# 2    0.001906
# 3    0.004658
# 4    0.005499
#
# [5 rows x 169 columns]

# %%
dfin2.to_csv("./classif/weekly10x10/classif10x10week_internet.csv")
dfin2.head()
# Out:
#    cellid  internet0  internet1  internet2  internet3  internet4  internet5  \
# 0    4273   0.055906   0.030629   0.021745   0.018926   0.022014   0.022073
# 1    4274   0.016595   0.012780   0.020191   0.013258   0.026107   0.026698
# 2    4275   0.018443   0.014786   0.023283   0.015955   0.029164   0.028976
# 3    4276   0.032342   0.026888   0.030985   0.023908   0.027834   0.023627
# 4    4277   0.035097   0.030121   0.034501   0.026530   0.030181   0.025607
#
#    internet6  internet7  internet8  ...  internet158  internet159  \
# 0   0.024597   0.036517   0.044328  ...     0.005829     0.006666
# 1   0.035218   0.052927   0.064451  ...     0.001942     0.001934
# 2   0.038924   0.057508   0.071008  ...     0.007784     0.007733
# 3   0.026941   0.031451   0.034790  ...     0.026643     0.033173
# 4   0.028333   0.032549   0.034643  ...     0.028757     0.036590
#
#    internet160  internet161  internet162  internet163  internet164  \
# 0     0.007004     0.006990     0.006883     0.007343     0.006635
# 1     0.001699     0.001645     0.002199     0.002489     0.001738
# 2     0.008294     0.008591     0.009586     0.009224     0.008699
# 3     0.041028     0.028142     0.042766     0.041874     0.040581
# 4     0.045672     0.029852     0.047242     0.046204     0.045094
#
#    internet165  internet166  internet167
# 0     0.005808     0.005313     0.005341
# 1     0.001408     0.001951     0.002383
# 2     0.008257     0.008323     0.008513
# 3     0.037097     0.041446     0.038482
# 4     0.041009     0.046538     0.042574
#
# [5 rows x 169 columns]
