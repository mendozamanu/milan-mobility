# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_val_score, cross_val_predict
#from sklearn.cluster import KMeans, OPTICS, AffinityPropagation

# %%
#Week 4-10 nov: smsin traffic
data = pd.read_csv("./classif/randomgrid/classif-randomgridweek_smsin.csv")
#data = pd.read_csv("./classif/10x10/classif10x10week_smsin.csv")
#data = pd.read_csv("./classif/20x20/classif20x20week_smsin.csv")

#data = pd.read_csv("./classif/randomgrid/classif-randomgridweekminute_smsin.csv")
#data = pd.read_csv("./classif/10x10/classif10x10weekminute_smsin.csv")
#data = pd.read_csv("./classif/20x20/classif20x20weekminute_smsin.csv")
data.head()
# Out:
#    Unnamed: 0  cellid    smsin0    smsin1    smsin2    smsin3    smsin4  \
# 0           0    5056  0.012011  0.004511  0.006024  0.001284  0.008181
# 1           1    5065  0.015551  0.016034  0.010442  0.001882  0.011099
# 2           2    5076  0.004295  0.000633  0.000654  0.000126  0.000022
# 3           3    5085  0.000532  0.000226  0.002825  0.000339  0.001135
# 4           4    5093  0.000565  0.000243  0.000000  0.000000  0.000244
#
#      smsin5    smsin6    smsin7  ...  smsin159  smsin160  smsin161  smsin162  \
# 0  0.009419  0.010504  0.061318  ...  0.064753  0.086046  0.083524  0.092893
# 1  0.006219  0.008772  0.032623  ...  0.057131  0.063292  0.070518  0.074217
# 2  0.000762  0.001013  0.005044  ...  0.008667  0.011443  0.011025  0.014575
# 3  0.000565  0.000758  0.004257  ...  0.005713  0.008367  0.009751  0.006174
# 4  0.000243  0.000000  0.000459  ...  0.001241  0.000405  0.001727  0.001938
#
#    smsin163  smsin164  smsin165  smsin166  smsin167  h/w
# ...

# %%
y = data.iloc[:,170] #h/w
x = data.iloc[:,2:170] #smsin for the whole week (24x7)
#y = data.iloc[:,1010] #h/w
#x = data.iloc[:,2:1010] #smsin for the whole week (24x7)

# %%
### Clustering ###
#model = MeanShift()
#model = KMeans(n_clusters=2)
#model = OPTICS(min_samples=3)
#model = AffinityPropagation(random_state=5)
# fit model and predict clusters
#yhat=model.fit_predict(x)
# retrieve unique clusters
#clusters = np.unique(yhat)
#print(len(yhat))
###            ###

# %%
knn = KNeighborsClassifier(n_neighbors=10)
scores1 = cross_val_score(knn, x, y, cv=5)
scores2 = cross_val_score(knn, x, y, cv=10)

# %%
#y_pred = cross_val_predict(knn, x, y, cv=10)

# %%
print("5 fold: %0.2f accuracy with a standard deviation of %0.2f" % (scores1.mean(), scores1.std()))
print("10 fold: %f accuracy with a standard deviation of %f" % (scores2.mean(), scores2.std()))
# Out:
# 5 fold: 0.69 accuracy with a standard deviation of 0.05
# 10 fold: 0.685833 accuracy with a standard deviation of 0.070076

# %%
data = pd.read_csv("./classif/randomgrid/classif-randomgridweek_smsout.csv")
#data = pd.read_csv("./classif/10x10/classif10x10week_smsout.csv")
#data = pd.read_csv("./classif/20x20/classif20x20week_smsout.csv")

#data = pd.read_csv("./classif/randomgrid/classif-randomgridweekminute_smsout.csv")
#data = pd.read_csv("./classif/10x10/classif10x10weekminute_smsout.csv")
#data = pd.read_csv("./classif/20x20/classif20x20weekminute_smsout.csv")
data.head()
# Out:
#    Unnamed: 0  cellid   smsout0   smsout1   smsout2   smsout3   smsout4  \
# 0           0    5056  0.101734  0.071043  0.064414  0.059165  0.056025
# 1           1    5065  0.021726  0.029023  0.018900  0.008611  0.006542
# 2           2    5076  0.006605  0.001544  0.000899  0.000404  0.001280
# 3           3    5085  0.000635  0.000312  0.003905  0.001250  0.002031
# 4           4    5093  0.000116  0.000000  0.000000  0.000000  0.000000
#
#     smsout5   smsout6   smsout7  ...  smsout159  smsout160  smsout161  \
# 0  0.065650  0.061833  0.117566  ...   0.109311   0.111168   0.112425
# 1  0.010560  0.016914  0.050542  ...   0.045295   0.048744   0.046317
# 2  0.000433  0.002126  0.004368  ...   0.007004   0.003463   0.006186
# 3  0.000000  0.000472  0.003156  ...   0.004334   0.006482   0.009256
# 4  0.000000  0.000000  0.000260  ...   0.001008   0.000857   0.002200
#
#    smsout162  smsout163  smsout164  smsout165  smsout166  smsout167  h/w
# ...

# %%
y = data.iloc[:,170] #h/w
x = data.iloc[:,2:170] #smsin for the whole week (24x7)
#y = data.iloc[:,1010] #h/w
#x = data.iloc[:,2:1010] #smsin for the whole week (24x7)

# %%
knn = KNeighborsClassifier(n_neighbors=10)
scores1 = cross_val_score(knn, x, y, cv=5)
scores2 = cross_val_score(knn, x, y, cv=10)

# %%
print("5 fold: %0.2f accuracy with a standard deviation of %0.2f" % (scores1.mean(), scores1.std()))
print("10 fold: %f accuracy with a standard deviation of %f" % (scores2.mean(), scores2.std()))
# Out:
# 5 fold: 0.72 accuracy with a standard deviation of 0.03
# 10 fold: 0.710167 accuracy with a standard deviation of 0.089593

# %%
data = pd.read_csv("./classif/randomgrid/classif-randomgridweek_callin.csv")
#data = pd.read_csv("./classif/10x10/classif10x10week_callin.csv")
#data = pd.read_csv("./classif/20x20/classif20x20week_callin.csv")

#data = pd.read_csv("./classif/randomgrid/classif-randomgridweekminute_callin.csv")
#data = pd.read_csv("./classif/10x10/classif10x10weekminute_callin.csv")
#data = pd.read_csv("./classif/20x20/classif20x20weekminute_callin.csv")
data.head()
# Out:
#    Unnamed: 0  cellid   callin0   callin1   callin2   callin3   callin4  \
# 0           0    5056  0.008915  0.006892  0.003664  0.000398  0.004511
# 1           1    5065  0.000592  0.002209  0.001151  0.000000  0.001722
# 2           2    5076  0.000160  0.000128  0.000454  0.000032  0.000519
# 3           3    5085  0.000012  0.000174  0.001245  0.000000  0.000174
# 4           4    5093  0.000043  0.000000  0.000043  0.000000  0.000000
#
#     callin5   callin6   callin7  ...  callin159  callin160  callin161  \
# 0  0.004170  0.015551  0.056063  ...   0.067714   0.060580   0.095011
# 1  0.004968  0.002596  0.030116  ...   0.056429   0.049032   0.092697
# 2  0.000454  0.000486  0.006036  ...   0.010266   0.011949   0.015749
# 3  0.000532  0.002501  0.003975  ...   0.004979   0.006084   0.004351
# 4  0.000000  0.000043  0.001081  ...   0.001208   0.002072   0.001912
#
#    callin162  callin163  callin164  callin165  callin166  callin167  h/w
# ...

# %%
y = data.iloc[:,170] #h/w
x = data.iloc[:,2:170] #smsin for the whole week (24x7)
#y = data.iloc[:,1010] #h/w
#x = data.iloc[:,2:1010] #smsin for the whole week (24x7)

# %%
knn = KNeighborsClassifier(n_neighbors=10)
scores1 = cross_val_score(knn, x, y, cv=5)
scores2 = cross_val_score(knn, x, y, cv=10)

# %%
print("5 fold: %0.2f accuracy with a standard deviation of %0.2f" % (scores1.mean(), scores1.std()))
print("10 fold: %f accuracy with a standard deviation of %f" % (scores2.mean(), scores2.std()))
# Out:
# 5 fold: 0.70 accuracy with a standard deviation of 0.06
# 10 fold: 0.714333 accuracy with a standard deviation of 0.070676

# %%
data = pd.read_csv("./classif/randomgrid/classif-randomgridweek_callout.csv")
#data = pd.read_csv("./classif/10x10/classif10x10week_callout.csv")
#data = pd.read_csv("./classif/20x20/classif20x20week_callout.csv")

#data = pd.read_csv("./classif/randomgrid/classif-randomgridweekminute_callout.csv")
#data = pd.read_csv("./classif/10x10/classif10x10weekminute_callout.csv")
#data = pd.read_csv("./classif/20x20/classif20x20weekminute_callout.csv")
data.head()
# Out:
#    Unnamed: 0  cellid  callout0  callout1  callout2  callout3  callout4  \
# 0           0    5056  0.011388  0.007216  0.003736  0.000000  0.000107
# 1           1    5065  0.013032  0.003555  0.000287  0.000209  0.002836
# 2           2    5076  0.004383  0.000249  0.000550  0.000032  0.000031
# 3           3    5085  0.000625  0.000506  0.000169  0.000338  0.000675
# 4           4    5093  0.000000  0.000363  0.000000  0.000000  0.000000
#
#    callout5  callout6  callout7  ...  callout159  callout160  callout161  \
# 0  0.000089  0.015308  0.061990  ...    0.051998    0.081521    0.104323
# 1  0.005350  0.010930  0.042503  ...    0.057220    0.062897    0.097356
# 2  0.000186  0.002820  0.019741  ...    0.013104    0.013892    0.026464
# 3  0.000172  0.000341  0.005252  ...    0.006095    0.006626    0.007404
# 4  0.000000  0.000000  0.001049  ...    0.000926    0.001049    0.000563
#
#    callout162  callout163  callout164  callout165  callout166  callout167  h/w
# ...

# %%
y = data.iloc[:,170] #h/w
x = data.iloc[:,2:170] #smsin for the whole week (24x7)
#y = data.iloc[:,1010] #h/w
#x = data.iloc[:,2:1010] #smsin for the whole week (24x7)

# %%
knn = KNeighborsClassifier(n_neighbors=10)
scores1 = cross_val_score(knn, x, y, cv=5)
scores2 = cross_val_score(knn, x, y, cv=10)

#y_pred = cross_val_predict(knn, x, y, cv=10)

# %%
print("5 fold: %0.2f accuracy with a standard deviation of %0.2f" % (scores1.mean(), scores1.std()))
print("10 fold: %f accuracy with a standard deviation of %f" % (scores2.mean(), scores2.std()))
# Out:
# 5 fold: 0.69 accuracy with a standard deviation of 0.04
# 10 fold: 0.685167 accuracy with a standard deviation of 0.052422

# %%
data = pd.read_csv("./classif/randomgrid/classif-randomgridweek_internet.csv")
#data = pd.read_csv("./classif/10x10/classif10x10week_internet.csv")
#data = pd.read_csv("./classif/20x20/classif20x20week_internet.csv")

#data = pd.read_csv("./classif/randomgrid/classif-randomgridweekminute_internet.csv")
#data = pd.read_csv("./classif/10x10/classif10x10weekminute_internet.csv")
#data = pd.read_csv("./classif/20x20/classif20x20weekminute_internet.csv")
data.head()
# Out:
#    Unnamed: 0  cellid  internet0  internet1  internet2  internet3  internet4  \
# 0           0    5056   0.084248   0.069885   0.063940   0.051539   0.049394
# 1           1    5065   0.043798   0.038791   0.032181   0.029329   0.026968
# 2           2    5076   0.006454   0.006126   0.006307   0.006273   0.006319
# 3           3    5085   0.004702   0.002743   0.002320   0.003885   0.001916
# 4           4    5093   0.001224   0.000614   0.000673   0.000700   0.000764
#
#    internet5  internet6  internet7  ...  internet159  internet160  \
# 0   0.047676   0.060493   0.104546  ...     0.132300     0.121041
# 1   0.029614   0.031620   0.057980  ...     0.068400     0.068772
# 2   0.006829   0.008556   0.011719  ...     0.010625     0.010742
# 3   0.003082   0.005856   0.005418  ...     0.009835     0.006834
# 4   0.000706   0.001128   0.000664  ...     0.002381     0.002431
#
#    internet161  internet162  internet163  internet164  internet165  \
# ...

# %%
y = data.iloc[:,170] #h/w
x = data.iloc[:,2:170] #smsin for the whole week (24x7)
#y = data.iloc[:,1010] #h/w
#x = data.iloc[:,2:1010] #smsin for the whole week (24x7)

# %%
knn = KNeighborsClassifier(n_neighbors=10)
scores1 = cross_val_score(knn, x, y, cv=5)
scores2 = cross_val_score(knn, x, y, cv=10)

# %%
print("5 fold: %0.2f accuracy with a standard deviation of %0.2f" % (scores1.mean(), scores1.std()))
print("10 fold: %f accuracy with a standard deviation of %f" % (scores2.mean(), scores2.std()))
# Out:
# 5 fold: 0.67 accuracy with a standard deviation of 0.06
# 10 fold: 0.665333 accuracy with a standard deviation of 0.079878

# %%
#y_pred = cross_val_predict(knn, x, y, cv=10)
#print(y_pred)

# %%
#predicted = pd.DataFrame(np.transpose(y_pred),columns=['predicted'])
#predicted['cellid']=data2.cellid
#predicted.append(np.transpose(y_pred))
#predicted.head()

# %%
#predicted.to_csv('./csv/predicted_si20.csv')
